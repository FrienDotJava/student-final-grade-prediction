# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv('student-mat.csv', sep=';')

df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %% [markdown]
# # Check for missing or duplicated data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
print('Number of duplicated data: ', df.duplicated().sum())
# Out:
# Number of duplicated data:  0

# %%
print("Number of empty data:")
df.isna().sum()
# Out:
# Number of empty data:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.replace({
    'yes':1,
    'no':0
}, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
categorical_color = sns.color_palette("Set2")
numerical_color = sns.color_palette("mako", 8)

# %% [markdown]
# ## Feature distribution

# %% [markdown]
# ### All features

# %%
# Count number of features
num_vars = df.shape[1]
 
# Determine number of rows and columns
n_cols = 4
n_rows = -(-num_vars // n_cols) 
 
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))
 
# Flatten axes array to ease iteration if needed
axes = axes.flatten()
 
# Plot every features
for i, column in enumerate(df.columns):
    df[column].hist(ax=axes[i], bins=20, edgecolor='black')
    axes[i].set_title(column)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')
 
# Delete unused subplot, if exist
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
 
plt.tight_layout()
plt.show()

# %%
labels_bad_good = ['Very Bad', 'Bad', 'Normal', 'Good', 'Very Good']
bad_good_order = {1: 'Very Bad', 2: 'Bad', 3: 'Normal', 4: 'Good', 5: 'Very Good'}

labels_low_high = ['Very Low', 'Low', 'Normal', 'High', 'Very High']
low_high_order = {1: 'Very Low', 2: 'Low', 3: 'Normal', 4: 'High', 5: 'Very High'}

study_labels = ['<2 hours', '2 to 5 hours', '5 to 10 hours', '>10 hours']
study_order= {1: '<2 hours', 2: '2 to 5 hours', 3: '5 to 10 hours', 4: '>10 hours'}
df_cat = df.copy()

df_cat['health'] = pd.Categorical(
    df_cat['health'].map(bad_good_order),
    categories=labels_bad_good,
    ordered=True
)
df_cat['Dalc'] = pd.Categorical(
    df_cat['Dalc'].map(low_high_order),
    categories=labels_low_high,
    ordered=True
)
df_cat['Walc'] = pd.Categorical(
    df_cat['Walc'].map(low_high_order),
    categories=labels_low_high,
    ordered=True
)
df_cat['goout'] = pd.Categorical(
    df_cat['goout'].map(low_high_order),
    categories=labels_low_high,
    ordered=True
)
df_cat['freetime'] = pd.Categorical(
    df_cat['freetime'].map(low_high_order),
    categories=labels_low_high,
    ordered=True
)
df_cat['studytime'] = pd.Categorical(
    df_cat['studytime'].map(study_order),
    categories=study_labels,
    ordered=True
)

df_cat
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# ### School Analysis

# %%
gp_df = df[df.school == 'GP']
ms_df = df[df.school == 'MS']

# %%
labels = df.school.unique()

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,6))
plt.suptitle('Number of students between Gabriel Pereira (GP) and Mousinho da Silveira (MS')
ax1.pie(df.school.value_counts(), labels=labels, autopct='%1.2f%%', colors=categorical_color)
ax2.bar(labels, df.school.value_counts(), color=categorical_color)

plt.show()

# %%
labels = gp_df['reason'].value_counts().sort_values(ascending=False).index

for i in range(labels.size):
    labels = labels.map(lambda x: 'Course preference' if x == 'course' else 'Close to Home' if x == 'home' else 'School Reputation' if x == 'reputation' else x)

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,6))
plt.suptitle('Reasons Students Choose Gabriel Pereira (GP)')
ax1.pie(gp_df.reason.value_counts(), labels=labels, autopct='%1.2f%%', colors=categorical_color)
ax2.bar(labels, gp_df.reason.value_counts(), color=categorical_color)
ax2.tick_params(axis='x', labelrotation=45)

plt.show()

# %%
labels = ms_df['reason'].value_counts().sort_values(ascending=False).index
for i in range(labels.size):
    labels = labels.map(lambda x: 'Course preference' if x == 'course' else 'Close to Home' if x == 'home' else 'School Reputation' if x == 'reputation' else x)

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,6))
plt.suptitle('Reasons Students Choose Mousinho da Silveira (MS)')
ax1.pie(ms_df.reason.value_counts(), labels=labels, autopct='%1.2f%%', colors=categorical_color)
ax2.bar(labels, ms_df.reason.value_counts(), color=categorical_color)

ax2.tick_params(axis='x', labelrotation=45)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,8))
ax1.pie(gp_df.schoolsup.value_counts(), labels=gp_df.schoolsup.unique(), autopct='%1.2f%%', colors=categorical_color)
ax1.set_title('Students in Gabriel Pereira That Receive School Support')
ax2.pie(ms_df.schoolsup.value_counts(), labels=ms_df.schoolsup.unique(), autopct='%1.2f%%', colors=[categorical_color[1]])
ax2.set_title('Students in Mousinho da Silveira That Receive School Support')

plt.show()

# %%
absence_school = df.groupby(by='school').absences.mean().sort_values(ascending=False).reset_index()

plt.bar(absence_school.school, absence_school.absences, color=categorical_color)

plt.title("Average Absences Between Schools")
plt.show()

# %%
fig, axes = plt.subplots(3, 1, figsize=(5, 14))
sns.boxenplot(data=df, x="school", y='G1', hue="school", ax=axes[0])
sns.boxenplot(data=df, x="school", y='G2', hue="school", ax=axes[1])
sns.boxenplot(data=df, x="school", y='G3', hue="school", ax=axes[2])
axes[0].set_title('Students First Period Grade Between Two Schools')
axes[1].set_title('Students Second Period Grade Between Two Schools')
axes[2].set_title('Students Final Grade Between Two Schools')
axes[0].set_xlabel(None)
axes[0].set_ylabel(None)
axes[1].set_xlabel(None)
axes[1].set_ylabel(None)
axes[2].set_xlabel(None)
axes[2].set_ylabel(None)
plt.show()

# %% [markdown]
# ### Student Analysis

# %%
weekday = df.groupby(by='sex').Dalc.mean().sort_values(ascending=False).reset_index()
weekend = df.groupby(by='sex').Walc.mean().sort_values(ascending=False).reset_index()

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,5))
ax1.bar(weekday.sex, weekday.Dalc, color=categorical_color)
ax2.bar(weekend.sex, weekend.Walc, color=categorical_color)
ax1.set_title('Weekday')
ax2.set_title('Weekend')

ax1.set_ylim(0, 3)
ax2.set_ylim(0, 3)
plt.suptitle("Average Alcohol Consumption By Gender")
plt.show()

# %%
df_male = df_cat[df_cat['sex']=='M']
df_female = df_cat[df_cat['sex']=='F']

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,5))
ax1.bar(labels_low_high, df_male.Dalc.value_counts(sort=False), color=numerical_color)
ax2.bar(labels_low_high, df_female.Dalc.value_counts(sort=False), color=numerical_color)

ax1.set_title("Male")
ax2.set_title("Female")

ax1.set_ylim(0,170)
ax2.set_ylim(0,170)
plt.suptitle('Alcohol Comsumption Distribution on Weekday')
plt.show()

# %%
df_male = df_cat[df_cat['sex']=='M']
df_female = df_cat[df_cat['sex']=='F']

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,5))
ax1.bar(labels_low_high, df_male.Walc.value_counts(sort=False), color=numerical_color)
ax2.bar(labels_low_high, df_female.Walc.value_counts(sort=False), color=numerical_color)

ax1.set_title("Male")
ax2.set_title("Female")

ax1.set_ylim(0,170)
ax2.set_ylim(0,170)
plt.suptitle('Alcohol Comsumption Distribution on Weekend')
plt.show()

# %%
absence = df.groupby(by='sex').absences.mean().sort_values(ascending=False).reset_index()

plt.bar(absence.sex, absence.absences, color=categorical_color)

plt.title("Average Absences By Gender")
plt.show()

# %%
df_male = df_cat[df_cat['sex']=='M']
df_female = df_cat[df_cat['sex']=='F']

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,5))
ax1.bar(study_labels, df_male.studytime.value_counts(sort=False), color=categorical_color)
ax2.bar(study_labels, df_female.studytime.value_counts(sort=False), color=categorical_color)

ax1.set_title("Male")
ax2.set_title("Female")

ax1.set_ylim(0,120)
ax2.set_ylim(0,120)
plt.suptitle('Study Time Distribution')
plt.show()

# %%
df_male = df[df['sex']=='M']
df_female = df[df['sex']=='F']

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,5))
ax1.bar(df_male.age.unique(), df_male.age.value_counts(), color=numerical_color)
ax2.bar(df_female.age.unique(), df_female.age.value_counts(), color=numerical_color)

ax1.set_title("Age Distribution of Male Students")
ax2.set_title("Age Distribution of Female Students")
plt.show()

# %%
df_male = df_cat[df_cat['sex']=='M']
df_female = df_cat[df_cat['sex']=='F']
labels = ['Very Bad', 'Bad', 'Normal', 'Good', 'Very Good']
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,5))
ax1.bar(labels, df_male.health.value_counts(sort=False), color=numerical_color)
ax2.bar(labels, df_female.health.value_counts(sort=False), color=numerical_color)

ax1.set_ylim(0,90)
ax2.set_ylim(0,90)

ax1.set_title("Health Condition of Male Students")
ax2.set_title("Health Condition of Female Students")
plt.show()

# %% [markdown]
# ### Correlation

# %%
cat_columns = df.select_dtypes(include='object').columns

df_one_hot = pd.get_dummies(df, columns=cat_columns)
df_one_hot
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 390   20     2     2           1          2         2       5         5
# 391   17     3     1           2          1         0       2         4
# 392   21     1     1           1          1         3       5         5
# 393   18     3     2           3          1         0       4         4
# 394   19     1     1           1          1         0       3         2
#
#      goout  Dalc  ...  activities_0  activities_1  nursery_0  nursery_1  \
# ...

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df_one_hot.corr()
 
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
# Correlation between target value
target_corr = df_one_hot.corr()['G3']
 
# sort result
target_corr_sorted = target_corr.abs().sort_values(ascending=False)
 
plt.figure(figsize=(10, 6))
target_corr_sorted.plot(kind='bar')
plt.title(f'Correlation with Final Grade (G3)')
plt.xlabel('Variables')
plt.ylabel('Correlation Coefficient')
plt.show()

# %% [markdown]
# # Train Test Split

# %%
X = df_one_hot.drop('G3', axis=1)
y = df_one_hot.G3

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print('Train size:', len(X_train))
print('Test size:', len(X_test))
# Out:
# Train size: 316
# Test size: 79

# %% [markdown]
# # Linear Regression

# %%
linear = LinearRegression()
ridge = Ridge()
lasso = Lasso()

linear.fit(X_train_scaled, y_train)
ridge.fit(X_train_scaled, y_train)
lasso.fit(X_train_scaled, y_train)
# Out:
# Lasso()

# %%
y_pred = linear.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Linear Regression')
print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# Linear Regression
# Mean Absolute Error: 1.62
# Mean Squared Error: 5.59
# R2: 0.73

# %%
y_pred = ridge.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Ridge Regression')
print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# Ridge Regression
# Mean Absolute Error: 1.65
# Mean Squared Error: 5.65
# R2: 0.72

# %%
y_pred = lasso.predict(X_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Lasso Regression')
print(f"Mean Absolute Error: {mae:.2f}")
print(f"Mean Squared Error: {mse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# Lasso Regression
# Mean Absolute Error: 1.42
# Mean Squared Error: 4.96
# R2: 0.76
